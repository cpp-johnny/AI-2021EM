# %%
# import the library

import math
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# get the stock quote
df = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2021-05-28')
# show the data
df

# visualise the closing price history
plt.figure(figsize=(16,8))
plt.title('AAPL Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-2-da3e46b8a33b> in <module>
#      12
#      13 # get the stock quote
# ---> 14 df = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2021-05-28')
#      15 # show the data
#      16 df
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /usr/local/lib/python3.8/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     374
#     375     if data_source == "yahoo":
# --> 376         return YahooDailyReader(
#     377             symbols=name,
#     378             start=start,
#
# ...

# %%
# import the library

import math
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# get the stock quote
df = web.DataReader('FB', data_source='yahoo', start='2012-01-01', end='2021-05-28')
# show the data
df

# visualise the closing price history
plt.figure(figsize=(16,8))
plt.title('FB Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# import the library

import math
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# get the stock quote
df = web.DataReader('TSLA', data_source='yahoo', start='2012-01-01', end='2021-05-28')
# show the data
df

# visualise the closing price history
plt.figure(figsize=(16,8))
plt.title('TSLA Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# import the library

import math
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# get the stock quote
df = web.DataReader('GME', data_source='yahoo', start='2012-01-01', end='2021-05-28')
# show the data
df

# visualise the closing price history
plt.figure(figsize=(16,8))
plt.title('GME Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# import the library

import math
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# get the stock quote
df = web.DataReader('CC3.SI', data_source='yahoo', start='2012-01-01', end='2021-05-28')
# show the data
df

# visualise the closing price history
plt.figure(figsize=(16,8))
plt.title('CC3.SI Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# import the library

import math
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# get the stock quote
df = web.DataReader('Z74.SI', data_source='yahoo', start='2012-01-01', end='2021-05-28')
# show the data
df

# visualise the closing price history
plt.figure(figsize=(16,8))
plt.title('Z74.I Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# import the library

import math
import numpy as np
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# get the stock quote
df = web.DataReader('GOOG', data_source='yahoo', start='2012-01-01', end='2021-05-28')
# show the data
df

# visualise the closing price history
plt.figure(figsize=(16,8))
plt.title('GOOG Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()
